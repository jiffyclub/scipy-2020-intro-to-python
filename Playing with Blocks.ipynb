# %% [markdown]
# After working through the exercises in this notebook you should be familiar with Python variables, indexing, [for loops][for], and [if statements][if].
#
# [for]: http://docs.python.org/2/reference/compound_stmts.html#the-for-statement
# [if]: http://docs.python.org/2/reference/compound_stmts.html#the-if-statement

# %%
from ipythonblocks import BlockGrid, colors, show_color, show_color_triple

# %% [markdown]
# [IPython help features](https://jakevdp.github.io/PythonDataScienceHandbook/01.01-help-and-documentation.html)

# %%
BlockGrid?

# %% [markdown]
# These blocks with `In[ ]:` and `Out[ ]:` next to them are "cells". Jupyter "echos" whatever is on the last line of a cell.

# %%
BlockGrid(4, 5)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksb4fa60e8-c058-4aa9-86b6-ca2a1d2dc347 td {border: 1px solid white;}</style><table id="blocksb4fa60e8-c058-4aa9-86b6-ca2a1d2dc347" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><
# ...

# %% [markdown]
# Use an `=` to assign something (on the right side of the `=`) to the name you want it to have (on the left side of the `=`).

# %%
grid = BlockGrid(5, 5, fill=colors.RosyBrown)

# %%
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks379a0bf6-e783-4eec-904d-5a08d0e1f259 td {border: 1px solid white;}</style><table id="blocks379a0bf6-e783-4eec-904d-5a08d0e1f259" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 1]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 2]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 3]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 4]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (188, 143, 143)" style=
# ...

# %% [markdown]
# `grid.show()` is another way to get a grid displayed, it's especially useful if you can't echo the grid on the last line of a cell.
#
# `.show` is a "method" on the `grid` instance. It's like a function attached to this particular grid. Note the parentheses used to "call" the method (and to call the `BlockGrid` above when making `grid`).

# %%
grid.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks6682281b-da81-4527-bd9b-65e4cafc7cb4 td {border: 1px solid white;}</style><table id="blocks6682281b-da81-4527-bd9b-65e4cafc7cb4" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 1]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 2]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 3]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 4]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (188, 143, 143)" style=
# ...

# %% [markdown]
# The `show_color` and `show_color_triple` functions are useful for previewing colors. The `colors` object/dictionary has a bunch of useful preset colors.

# %%
show_color_triple(colors.Bisque)
# Out:
# <div style="height: 60px; min-width: 200px; background-color: rgb(255, 228, 196)"></div>

# %%
colors.AliceBlue
# Out:
# Color(red=240, green=248, blue=255)

# %% [markdown]
# When pulling an individual block out of a grid use square brackets and specify a row and column:
# `grid[row_index, column_index`.
# Python is zero-indexed.

# %%
block = grid[0, 0]
block
# Out:
# Block(188, 143, 143, size=20)

# %% [markdown]
# `.rgb` is an "attribute" of blocks that has the "red, green, blue" values of the color of the block.
# These these integers can have values from 0 - 255 and the combination of the three specifies the color of the block.

# %%
block.rgb
# Out:
# (188, 143, 143)

# %% [markdown]
# We can assign a new triplet of color integers to the `.rgb` attribute to change the color of a block.

# %%
block.rgb = colors.AliceBlue
block
# Out:
# Block(240, 248, 255, size=20)

# %% [markdown]
# We can see further information about a block using the `print` and `type` functions.

# %%
print(block)
# Out:
# Block [0, 0]
# Color: (240, 248, 255)

# %%
type(block)
# Out:
# ipythonblocks.Block

# %% [markdown]
# Note that changing the color of the block variable above also changed the color of the block in the grid.
# When we ran `block = grid[0, 0]` above we created a new name (`block`) that referenced the top-left cell
# of the grid. We did _not_ make a copy of that block.

# %%
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks44aed9bf-4319-4cb1-9c22-39e4a514f4b1 td {border: 1px solid white;}</style><table id="blocks44aed9bf-4319-4cb1-9c22-39e4a514f4b1" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (240, 248, 255)" style="width: 20px; height: 20px;background-color: rgb(240, 248, 255);"></td><td title="Index: [0, 1]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 2]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 3]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 4]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (188, 143, 143)" style=
# ...

# %% [markdown]
# We could also change the color of the top-left block without first pulling it into a variable.

# %%
grid[0, 0].rgb = colors.Cyan
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks67226b49-fcf7-4bfd-82cf-7bd56625a676 td {border: 1px solid white;}</style><table id="blocks67226b49-fcf7-4bfd-82cf-7bd56625a676" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 255);"></td><td title="Index: [0, 1]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 2]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 3]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 4]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (188, 143, 143)" style="wid
# ...

# %% [markdown]
# Note also that assigning the `grid` variable to a new variable (`new_grid` here) there is still _no copy_. Modifying `new_grid` modifies the original `grid` as well because they are different names for the same thing.

# %%
new_grid = grid
new_grid[1, 1].rgb = colors.DarkCyan
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks5cc7e571-4362-4791-90c7-721aba0de7ed td {border: 1px solid white;}</style><table id="blocks5cc7e571-4362-4791-90c7-721aba0de7ed" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 255);"></td><td title="Index: [0, 1]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 2]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 3]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 4]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (188, 143, 143)" style="wid
# ...

# %%
grid[2, 2] = colors.FireBrick
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blockse38d32cb-1a16-4304-b30b-c1d846997614 td {border: 1px solid white;}</style><table id="blockse38d32cb-1a16-4304-b30b-c1d846997614" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 255);"></td><td title="Index: [0, 1]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 2]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 3]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 4]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (188, 143, 143)" style="wid
# ...

# %% [markdown]
# The `grid` object doesn't have a `.rgb` attribute.
# Python lets you create one by assigning something to it, but nothing happens to the appearance of the grid.

# %%
grid.rgb = colors.Gold
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks43998a38-ca40-4dcd-8e0e-2115a52a4f91 td {border: 1px solid white;}</style><table id="blocks43998a38-ca40-4dcd-8e0e-2115a52a4f91" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 255);"></td><td title="Index: [0, 1]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 2]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 3]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 4]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (188, 143, 143)" style="wid
# ...

# %% [markdown]
# Exercise 2: "Change the color of the block in the third row and fourth column."

# %%
grid[2, 3].rgb = colors.Black
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks79864074-2447-491a-b51f-1bacca30227e td {border: 1px solid white;}</style><table id="blocks79864074-2447-491a-b51f-1bacca30227e" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 255);"></td><td title="Index: [0, 1]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 2]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 3]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 4]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (188, 143, 143)" style="wid
# ...

# %% [markdown]
# Exercise 3: "Change the color of the block in the lower-right corner of the grid."

# %%
grid[4, 4].rgb = colors.Teal

# %%
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksa25e0bbe-1eae-4116-a7d4-6987fd3e457b td {border: 1px solid white;}</style><table id="blocksa25e0bbe-1eae-4116-a7d4-6987fd3e457b" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 255);"></td><td title="Index: [0, 1]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 2]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 3]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 4]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (188, 143, 143)" style="wid
# ...

# %% [markdown]
# Python also supports negative indexing, allowing you to index into the ends of containers without knowing
# how big they are.
# Index `-1` is the last item, index `-2` is the second-to-last item, etc.

# %%
grid[-1, -1].rgb = colors.Violet
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks9dd81261-5b4a-4738-89d7-e35133b6cd0a td {border: 1px solid white;}</style><table id="blocks9dd81261-5b4a-4738-89d7-e35133b6cd0a" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 255);"></td><td title="Index: [0, 1]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 2]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 3]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 4]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (188, 143, 143)" style="wid
# ...

# %% [markdown]
# If you wanted to show two or more grids in the output of a notebook cell you could use the `.show()` method.

# %%
grid.show()
new_grid.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks7ed34091-593e-452b-94cb-98e5e5cfbdda td {border: 1px solid white;}</style><table id="blocks7ed34091-593e-452b-94cb-98e5e5cfbdda" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 255);"></td><td title="Index: [0, 1]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 2]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 3]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 4]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (188, 143, 143)" style="wid
# ...

# %% [markdown]
# Exercise 4: "Use negative indexing to change the color of the block in the second row
# and first column."

# %%
grid[-4, -5].rgb = colors.Wheat
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks2d98b45b-2f08-46e1-963d-8423008082eb td {border: 1px solid white;}</style><table id="blocks2d98b45b-2f08-46e1-963d-8423008082eb" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 255);"></td><td title="Index: [0, 1]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 2]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 3]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td><td title="Index: [0, 4]&#10;Color: (188, 143, 143)" style="width: 20px; height: 20px;background-color: rgb(188, 143, 143);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (245, 222, 179)" style="wid
# ...

# %% [markdown]
# ## Loops
#
# Python's `for thing in container:` syntax lets you iterate over whatever is in `container`.
# But, note that what exactly this means varies depending on what `container` is.
# In the case of our grids, each iteration of the loop gives us one of the blocks from the grid.
#
# As an example we could change the color of every block in the grid using a loop.

# %%
for block in grid:
    block.rgb = colors.HotPink
    
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks9df54195-f4f7-4e39-bb29-c12893944ecd td {border: 1px solid white;}</style><table id="blocks9df54195-f4f7-4e39-bb29-c12893944ecd" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 105, 180)" style="width: 20px; height: 20px;background-color: rgb(255, 105, 180);"></td><td title="Index: [0, 1]&#10;Color: (255, 105, 180)" style="width: 20px; height: 20px;background-color: rgb(255, 105, 180);"></td><td title="Index: [0, 2]&#10;Color: (255, 105, 180)" style="width: 20px; height: 20px;background-color: rgb(255, 105, 180);"></td><td title="Index: [0, 3]&#10;Color: (255, 105, 180)" style="width: 20px; height: 20px;background-color: rgb(255, 105, 180);"></td><td title="Index: [0, 4]&#10;Color: (255, 105, 180)" style="width: 20px; height: 20px;background-color: rgb(255, 105, 180);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (255, 105, 180)" style=
# ...

# %% [markdown]
# Exercise 5: "Use a `for` loop to change the color of every block in your grid."
#
# The `.animate()` method will show you the state of grid as the loop runs.
# (But you'll only see the final state of the grid after the loop if you're reading this later.)

# %%
for block in grid.animate():
    block.rgb = colors.Honeydew
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks12c881f7-f0fc-40fb-bea8-036f00d9238d td {border: 1px solid white;}</style><table id="blocks12c881f7-f0fc-40fb-bea8-036f00d9238d" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (240, 255, 240)" style="width: 20px; height: 20px;background-color: rgb(240, 255, 240);"></td><td title="Index: [0, 1]&#10;Color: (240, 255, 240)" style="width: 20px; height: 20px;background-color: rgb(240, 255, 240);"></td><td title="Index: [0, 2]&#10;Color: (240, 255, 240)" style="width: 20px; height: 20px;background-color: rgb(240, 255, 240);"></td><td title="Index: [0, 3]&#10;Color: (240, 255, 240)" style="width: 20px; height: 20px;background-color: rgb(240, 255, 240);"></td><td title="Index: [0, 4]&#10;Color: (240, 255, 240)" style="width: 20px; height: 20px;background-color: rgb(240, 255, 240);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (240, 255, 240)" style=
# ...

# %% [markdown]
# ## Ifs
#
# `if` statements allow us to only execute code when a given condition is true.
# The `==` comparator checks whether two things are equal.
# Don't get it confused with the single `=` used for assignment!

# %%
for block in grid.animate():
    if block.row == 2:
        block.rgb = colors.PapayaWhip
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks38dc4e82-9135-4433-8ec8-1b288c06643a td {border: 1px solid white;}</style><table id="blocks38dc4e82-9135-4433-8ec8-1b288c06643a" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (240, 255, 240)" style="width: 20px; height: 20px;background-color: rgb(240, 255, 240);"></td><td title="Index: [0, 1]&#10;Color: (240, 255, 240)" style="width: 20px; height: 20px;background-color: rgb(240, 255, 240);"></td><td title="Index: [0, 2]&#10;Color: (240, 255, 240)" style="width: 20px; height: 20px;background-color: rgb(240, 255, 240);"></td><td title="Index: [0, 3]&#10;Color: (240, 255, 240)" style="width: 20px; height: 20px;background-color: rgb(240, 255, 240);"></td><td title="Index: [0, 4]&#10;Color: (240, 255, 240)" style="width: 20px; height: 20px;background-color: rgb(240, 255, 240);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (240, 255, 240)" style=
# ...

# %% [markdown]
# How would I figure out that blocks had a `.row` attribute?
# I could use the `?` help feature to read the docstring or use `block.<tab>` to see available methods
# and attributes.
# But, note that `block.<tab>` only works if block is an existing variable with something assigned to it
# when you press tab. That's not the case when writing the loop above.

# %%
block = grid[0, 0]
block?

# %% [markdown]
# Exercise 6: "Use a `for` loop and an `if` statement to change the color of every block
# in the fourth *column* of your grid."
#
# Blocks also have a `.col` attribute that has the column index of the block.

# %%
for block in grid.animate():
    if block.col == 3:
        block.rgb = colors.Magenta
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks44d25cee-64f1-498c-8a7c-40b66476e207 td {border: 1px solid white;}</style><table id="blocks44d25cee-64f1-498c-8a7c-40b66476e207" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (240, 255, 240)" style="width: 20px; height: 20px;background-color: rgb(240, 255, 240);"></td><td title="Index: [0, 1]&#10;Color: (240, 255, 240)" style="width: 20px; height: 20px;background-color: rgb(240, 255, 240);"></td><td title="Index: [0, 2]&#10;Color: (240, 255, 240)" style="width: 20px; height: 20px;background-color: rgb(240, 255, 240);"></td><td title="Index: [0, 3]&#10;Color: (255, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 255);"></td><td title="Index: [0, 4]&#10;Color: (240, 255, 240)" style="width: 20px; height: 20px;background-color: rgb(240, 255, 240);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (240, 255, 240)" style="wid
# ...

# %% [markdown]
# `elif` and `else` allow us to write separate blocks of code that run under different conditions.
# Only one of these branches will run for each `block` in the grid.
# `else` applies to anything not matched by an `if` or `elif` above it.

# %%
for block in grid.animate():
    if block.row == 0:
        block.rgb = colors.Black
    elif block.row == 2:
        block.rgb = colors.White
    else:
        block.rgb = colors.Blue
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks8c13a338-79ca-4762-8fdb-81c274df03a4 td {border: 1px solid white;}</style><table id="blocks8c13a338-79ca-4762-8fdb-81c274df03a4" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 255);"></
# ...

# %% [markdown]
# Exercise 7: "Augment your code from Exercise 6 with an `elif` and an `else` to change the
# color of all blocks in your grid. But make the second column red, the
# third column green, and all the other blocks gold."

# %%
for block in grid.animate():
    if block.col == 1:
        block.rgb = colors.Red
    elif block.col == 2:
        block.rgb = colors.Green
    else:
        block.rgb = colors.Gold
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksff71faca-cfd3-428e-a243-7c0c2bd32c05 td {border: 1px solid white;}</style><table id="blocksff71faca-cfd3-428e-a243-7c0c2bd32c05" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 215, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 215, 0);"></td><td title="Index: [0, 1]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 128, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 128, 0);"></td><td title="Index: [0, 3]&#10;Color: (255, 215, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 215, 0);"></td><td title="Index: [0, 4]&#10;Color: (255, 215, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 215, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (255, 215, 0)" style="width: 20px; height: 20px;bac
# ...

# %% [markdown]
# Other Python comparators:
#
# - `<` less than
# - `<=` less than or equal
# - `>` greater than
# - `>=` greater than or equal
# - `!=` not equal

# %% [markdown]
# `and` and `or` allow us to construct more complicated `if` expressions.
# When using `or` only one of the conditions needs to be true for the branch to be executed.

# %%
for block in grid.animate():
    if block.col == 2 or block.col == 4:
        block.rgb = colors.Khaki
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks044e03c2-e317-4b7b-8251-23fd907eb485 td {border: 1px solid white;}</style><table id="blocks044e03c2-e317-4b7b-8251-23fd907eb485" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 215, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 215, 0);"></td><td title="Index: [0, 1]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (240, 230, 140)" style="width: 20px; height: 20px;background-color: rgb(240, 230, 140);"></td><td title="Index: [0, 3]&#10;Color: (255, 215, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 215, 0);"></td><td title="Index: [0, 4]&#10;Color: (240, 230, 140)" style="width: 20px; height: 20px;background-color: rgb(240, 230, 140);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (255, 215, 0)" style="width: 20px; heig
# ...

# %% [markdown]
# Exercise 8: "Use an `if` with an `or` to change the color of the blocks in the first
# and fifth rows to black."

# %%
for block in grid.animate():
    if block.row == 0 or block.row == 4:
        block.rgb = colors.Black
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks340f6d95-2f70-4133-bed2-acd1857d05a1 td {border: 1px solid white;}</style><table id="blocks340f6d95-2f70-4133-bed2-acd1857d05a1" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (255, 215, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 215, 0);
# ...

# %% [markdown]
# If we want to make checks on the _color_ of the blocks here are some different ways to do that.

# %%
block = grid[1, 1]

# %%
block.rgb
# Out:
# (255, 0, 0)

# %%
block.rgb == (255, 0, 0)
# Out:
# True

# %%
block.rgb == colors.Red
# Out:
# True

# %%
block.red
# Out:
# 255

# %%
block.blue
# Out:
# 0

# %% [markdown]
# Exercise 9: "Use an `if` with an `and` condition to turn every block that is in the
# fourth column AND black to blue."
#
# When using `and` both of the conditions must be true in order for the branch to be executed.

# %%
for block in grid.animate():
    if block.col == 3 and block.rgb == colors.Black:
        block.rgb = colors.Blue
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks6fda2a9c-e861-4cce-953f-f4574609d277 td {border: 1px solid white;}</style><table id="blocks6fda2a9c-e861-4cce-953f-f4574609d277" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (255, 215, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 215,
# ...

# %% [markdown]
# You can use parentheses to specify an order of operations for `if` conditions.
# Absent parentheses `or` and `and` will be combined left to right.

# %%
for block in grid.animate():
    if (block.col == 1 or block.col == 2) and block.rgb == colors.Black:
        block.rgb = colors.Blue
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks123a4aac-751c-4fca-b952-6a4dbae06bf1 td {border: 1px solid white;}</style><table id="blocks123a4aac-751c-4fca-b952-6a4dbae06bf1" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (255, 215, 0)" style="width: 20px; height: 20px;background-color: rgb(2
# ...

# %% [markdown]
# ## `range`
#
# Sometimes we don't need to loop over every block in a grid because we know ahead of time we're
# only interested in some subset of them.
# The `range` function can help construct a sequence of integer values to use as indices while in the loop.
# [`range` documentation](https://docs.python.org/3.8/library/stdtypes.html#range)
#
# Note: the `stop` argument to range is not included in the result!

# %%
for index in range(5):
    print(index)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for index in range(5, 8):
    print(index)
# Out:
# 5
# 6
# 7

# %%
for index in range(5, 15, 3):
    print(index)
# Out:
# 5
# 8
# 11
# 14

# %% [markdown]
# Here we want to change the color of every block in the 2nd row, so we loop over a `range` that encompasses
# all the columns in the grid.

# %%
for column_index in range(grid.width):
    grid[1, column_index].rgb = colors.Orange

grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks0274028d-27af-4138-a4a3-6a72fdb3310b td {border: 1px solid white;}</style><table id="blocks0274028d-27af-4138-a4a3-6a72fdb3310b" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (255, 165, 0)" style="width: 20px; height: 20px;background-color: rgb(2
# ...

# %% [markdown]
# Exercise 10: "Make a new 20 by 20 block grid. Use a `for` loop with `range` to change the
# color of every block in the third, 10th, and 18th rows."
#
# Note the use of `grid.flash()` to briefly show the grid at each iteration since we're no longer
# using `grid.animate()`. We also need to echo `grid` on the last line (or use `grid.show()`
# after the loop) in order to see the final result.

# %%
grid = BlockGrid(20, 20)

# %%
for column_index in range(grid.width):
    grid[2, column_index].rgb = colors.YellowGreen
    grid[9, column_index].rgb = colors.YellowGreen
    grid[17, column_index].rgb = colors.YellowGreen
    grid.flash()

grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blockscfab33e2-c803-4664-8c2d-afbe9b95e7d1 td {border: 1px solid white;}</style><table id="blockscfab33e2-c803-4664-8c2d-afbe9b95e7d1" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title=
# ...

# %% [markdown]
# An alternate way of doing this is to have nested loops, the outer one for the columns we want to change and
# the inner one for the rows we want to change.
# Note that the `[2, 9, 17]` is a list with the row indices.
# (We can't use `range` for the row indices because they aren't evenly spaced.)

# %%
for column_index in range(grid.width):
    for row_index in [2, 9, 17]:
        grid[row_index, column_index].rgb = colors.Indigo
        grid.flash()

grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks14ecb7aa-5cd5-4f74-96b9-d640cf622dca td {border: 1px solid white;}</style><table id="blocks14ecb7aa-5cd5-4f74-96b9-d640cf622dca" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title=
# ...

# %% [markdown]
# Exercise 11: "Use nested `for` loops with `range` to change the color of the bottom-left
# quadrant of your 20 by 20 grid."
#
# Here we use some math instead of hard-coding the row and column indexes in our calls to `range`.
# The `//` operator does floor division, returning an integer and discarding any fractional component of the result
# (needed because `range` doesn't work with floating point inputs and `/` always returns a float).

# %%
for row_index in range(grid.height // 2, grid.height):
    for column_index in range(0, grid.width // 2):
        grid[row_index, column_index].rgb = colors.LavenderBlush

grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks21eb2ba2-5c1f-4fef-a59e-46d298b597c3 td {border: 1px solid white;}</style><table id="blocks21eb2ba2-5c1f-4fef-a59e-46d298b597c3" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title=
# ...

# %% [markdown]
# The `int` function will try to convert an input to an integer, it also truncates the input (does not round).

# %%
int(2.3)
# Out:
# 2

# %% [markdown]
# ## Slicing
#
# Slicing is an abbreviated, inline way of specifying a subset of a Python container.
# The syntax of a slice is `start:stop:step`, but not all of those are required.
#
# In this first example `5:15` means "from the 5th index up to but not including the 15th index".

# %%
grid[5:15, 5:15]
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksca8a8265-8813-4904-a097-beb9faae8e8c td {border: 1px solid white;}</style><table id="blocksca8a8265-8813-4904-a097-beb9faae8e8c" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title=
# ...

# %% [markdown]
# When the start or stop of a slice is not specified it means "from the beginning" or "until the end", respectively.

# %%
grid[:5, 15:]
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks02970ace-88bb-49d0-b521-3f62d938d804 td {border: 1px solid white;}</style><table id="blocks02970ace-88bb-49d0-b521-3f62d938d804" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><
# ...

# %% [markdown]
# A lone `:` means "include everything along this dimension" (in this case all the columns).

# %%
grid[:5, :]
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksc63fede6-15aa-419a-b3b3-3eb426acbaea td {border: 1px solid white;}</style><table id="blocksc63fede6-15aa-419a-b3b3-3eb426acbaea" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title=
# ...

# %% [markdown]
# We can assign a color to a slice of a grid to change the color of all the blocks in that slice.

# %%
grid[:5, :] = colors.Crimson
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks3b0ea046-8523-40cf-a3d3-689c5d968eac td {border: 1px solid white;}</style><table id="blocks3b0ea046-8523-40cf-a3d3-689c5d968eac" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 1]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 2]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 3]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 4]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 5]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;back
# ...

# %% [markdown]
# Exercise 12: "Try to get the same affects as in Exercises 10 & 11, but using slicing instead
# of `for` loops."

# %%
grid[2, :] = colors.Thistle
grid[9, :] = colors.Tomato
grid[17, :] = colors.Turquoise
grid[-10:, :10] = colors.Blue
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks9fb7c65f-3b64-422f-9640-1955990fa5e8 td {border: 1px solid white;}</style><table id="blocks9fb7c65f-3b64-422f-9640-1955990fa5e8" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 1]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 2]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 3]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 4]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 5]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;back
# ...

# %% [markdown]
# Slicing also supports specifying a step-size, very similar to `range`.
# Here `1::2` means "start at the first index, go through the end, and include every 2nd index".

# %%
grid[1::2, :] = colors.Teal
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks7b38867a-a413-45f1-a74a-03012d9a5564 td {border: 1px solid white;}</style><table id="blocks7b38867a-a413-45f1-a74a-03012d9a5564" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 1]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 2]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 3]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 4]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 5]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;back
# ...

# %% [markdown]
# ## Functions
#
# Functions are one way to package code and re-use it again and again.
# Note the `def` keyword indicating we're writing a function, the name of the function
# (here `fahr_to_celsius`), the parentheses, and the list of arguments inside the paretheses.
#
# The `return` statement is used to pass something back to the code that calls the function.
# A function can return multiple things by separating them with commas after the `return`:
# `return 1, 2, 3, 4`.

# %%
def fahr_to_celsius(temp):
    return ((temp - 32) * (5 / 9))

# %%
fahr_to_celsius(63)
# Out:
# 17.22222222222222

# %%
fahr_to_celsius(90)
# Out:
# 32.22222222222222

# %% [markdown]
# Exercise 13: "Write a function that takes a grid as input and returns a new grid with
# the colors inverted (e.g. white becomes black, black becomes white,
# yellow becomes ???)."

# %%
def invert_colors(input_grid):
    """
    Returns a new grid the same size as the input grid but with colors "inverted".
    
    """
    new_grid = input_grid.copy()
    
    for row_index in range(input_grid.height):
        for col_index in range(input_grid.width):
            new_grid[row_index, col_index].red = 255 - input_grid[row_index, col_index].red
            new_grid[row_index, col_index].blue = 255 - input_grid[row_index, col_index].blue
            new_grid[row_index, col_index].green = 255 - input_grid[row_index, col_index].green
    
    return new_grid

# %%
invert_colors(grid)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks663f4765-d1e2-479c-b33a-4d0d4fde814d td {border: 1px solid white;}</style><table id="blocks663f4765-d1e2-479c-b33a-4d0d4fde814d" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (35, 235, 195)" style="width: 20px; height: 20px;background-color: rgb(35, 235, 195);"></td><td title="Index: [0, 1]&#10;Color: (35, 235, 195)" style="width: 20px; height: 20px;background-color: rgb(35, 235, 195);"></td><td title="Index: [0, 2]&#10;Color: (35, 235, 195)" style="width: 20px; height: 20px;background-color: rgb(35, 235, 195);"></td><td title="Index: [0, 3]&#10;Color: (35, 235, 195)" style="width: 20px; height: 20px;background-color: rgb(35, 235, 195);"></td><td title="Index: [0, 4]&#10;Color: (35, 235, 195)" style="width: 20px; height: 20px;background-color: rgb(35, 235, 195);"></td><td title="Index: [0, 5]&#10;Color: (35, 235, 195)" style="width: 20px; height
# ...

# %% [markdown]
# Exercise 14: "Write a function that takes a grid and a color as input returns a new grid
# that is the input grid with an added border of the given color.
#
# BONUS: Make the color input argument optional."
#
# If the user doesn't supply a value for the `border_color` input it will default to `colors.Black`.

# %%
def add_border(input_grid, border_color=colors.Black):
    """
    Add a two-block border to the input grid.
    
    Specify the border color as a tuple of (red, green, blue) integers.
    
    """
    new_width = input_grid.width + 4
    new_height = input_grid.height + 4
    new_grid = BlockGrid(new_width, new_height, fill=border_color)
    
    for block in input_grid:
        new_grid[block.row + 2, block.col + 2].rgb = block.rgb
    
    return new_grid

# %%
add_border(grid, border_color=colors.Cyan)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks3400f3e2-4786-436f-9d5a-28158d7f7cee td {border: 1px solid white;}</style><table id="blocks3400f3e2-4786-436f-9d5a-28158d7f7cee" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 255);"></td><td title="Index: [0, 1]&#10;Color: (0, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 255);"></td><td title="Index: [0, 2]&#10;Color: (0, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 255);"></td><td title="Index: [0, 3]&#10;Color: (0, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 255);"></td><td title="Index: [0, 4]&#10;Color: (0, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 255);"></td><td title="Index: [0, 5]&#10;Color: (0, 255, 255)" style="width: 20px; height: 20px;back
# ...

# %% [markdown]
# Exercise 15: Write a function that can follow a list of directions
# (`'up'`, `'down'`, `'left'`, `'right'`) along a path, changing the color of
# blocks as it goes.
# An example function definition:
#
# ```python
# def path_color(grid, path, starting_point, color):
#     ...
# ```

# %%
def path_color(input_grid, path, starting_point, color):
    """
    Change the color of all the blocks along a path starting at starting_point.
    
    Specify the path as a sequence of 'up', 'down', 'left', 'right' strings.
    Specify the starting point as (row, column) tuple.
    Specify the color a (red, green, blue) tuple.
    
    """
    new_grid = input_grid.copy()
    
    # pull the location into separate row/col indices we can update individually
    current_row = starting_point[0]
    current_col = starting_point[1]
    
    # first, change the color of the block we're at
    new_grid[current_row, current_col].rgb = color
    
    # then move to the new location based on the path
    for direction in path:
        if direction == 'up':
            # one row higher in the grid
            current_row = current_row - 1
        elif direction == 'down':
            # one row lower
            current_row = current_row + 1
        elif direction == 'left':
            # one column to the left
            current_col = current_col - 1
        elif direction == 'right':
            # one column to the right
            current_col = current_col + 1
        
        # and update the new location's color
        new_grid[current_row, current_col].rgb = color
    
    return new_grid

# %%
path = (
    'right', 'right', 'down', 'right', 'down', 'down', 'left', 'down', 'down', 'right', 'right', 'right', 'up'
)

path_color(grid, path, (3, 4), colors.HotPink)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksd16aa888-953a-4fb1-9aae-3bfb2d29aaa3 td {border: 1px solid white;}</style><table id="blocksd16aa888-953a-4fb1-9aae-3bfb2d29aaa3" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 1]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 2]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 3]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 4]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;background-color: rgb(220, 20, 60);"></td><td title="Index: [0, 5]&#10;Color: (220, 20, 60)" style="width: 20px; height: 20px;back
# ...
